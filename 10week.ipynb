# %% [markdown]
# <a href="https://colab.research.google.com/github/zzzzryun/ForHomework/blob/main/10week.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 코드 9-1

# %%
import numpy as np

arr = np.array([1, 2, 3, 4, 5])
print(arr)
# Out:
# [1 2 3 4 5]

# %% [markdown]
# 코드 9-2

# %%
arr - np.array([1, 2, 3, 4, 5])
print(arr[1])
print(arr[1:4])
# Out:
# 2
# [2 3 4]

# %% [markdown]
# 코드 9-3

# %%
arr = np.array([[1,2,3],[4,5,6]])
print(arr)
print(arr[0,1])
print(arr[1,2])
# Out:
# [[1 2 3]
#  [4 5 6]]
# 2
# 6

# %% [markdown]
# 코드 9-5

# %%
arr = np.array([[1,2,3],[4,5,6]])
print(arr.shape)
# Out:
# (2, 3)

# %% [markdown]
# 코드 9-6

# %%
arr1 = np.array([[1,2,3],[4,5,6]])
arr2 = arr1.reshape(3,2)

print(arr2)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]

# %% [markdown]
# 코드 9-7

# %%
arr = np.array([2, 3, 4])
result = arr*2
print(result)
# Out:
# [4 6 8]

# %% [markdown]
# 코드 9-8

# %%
arr1 = np.array([2,3,4])
arr2 = np.array([5,6,7])
result = arr1+arr2
print(result)
# Out:
# [ 7  9 11]

# %% [markdown]
# 코드 9-9

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-1,1,100)
y = x**2

plt.figure(figsize = (5,3))
plt.plot(x,y,label='y=x^2')
plt.legend()
plt.show()
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# 코드 9-10

# %%
import matplotlib.pyplot as plt

year = [2006,2009,2012,2015,2018]
kor = [547,546,554,524,526]

plt.figure(figsize = (5,3))
plt.plot(year,kor)
plt.ylim(500,580)
plt.xlabel('year')
plt.ylabel('score')
plt.show()

# %% [markdown]
# 코드 9-11

# %%
year = [2006,2009,2012,2015,2018]
kor = [547,546,554,524,526]

ind = np.arange(len(year))

plt.figure(figsize = (5,3))
plt.plot(ind,kor)
plt.xticks(ind,year)
plt.ylim(500,580)
plt.xlabel('year')
plt.ylabel('score')
plt.show()

# %% [markdown]
# 코드 9-12

# %%
from matplotlib import color_sequences
nation = ['Korea','USA','Japan','France']
men = [175.5, 176.9, 172.1, 178.6]
women = [163.2, 163.3, 158.5, 164.5]
ind = np.arange(len(nation))

plt.figure(figsize = (5,3))
plt.bar(ind, men, color='b', label='men')
plt.bar(ind, women, color='r', label='women')
plt.ylim(130,190)
plt.xticks(ind,nation)
plt.legend()
plt.show()

# %% [markdown]
# 코드 9-13

# %%
from matplotlib import color_sequences
nation = ['Korea','USA','Japan','France']
men = [175.5, 176.9, 172.1, 178.6]
women = [163.2, 163.3, 158.5, 164.5]
ind = np.arange(len(nation))

plt.figure(figsize = (5,3))
plt.bar(ind-0.2, men, color='b', label='men', width=0.4)
plt.bar(ind+0.2, women, color='r', label='women', width=0.4)
plt.ylim(130,190)
plt.title('Height')
plt.ylabel('cm')
plt.xticks(ind,nation)
plt.legend()
plt.show()

# %% [markdown]
# 코드 9-14, 15

# %%
year = [2017,2018,2019,2020,2021]
spring = np.array([124.9, 383.5, 175.0, 173.7, 330.5])
summer = np.array([612.7, 620.6, 508.2, 1037.6, 612.8])
autumn = np.array([177.9, 351.3, 440.8, 270.4, 256.4])
winter = np.array([75.2, 68.7, 168.8, 47.8, 13.3])

plt.bar(year, spring, label='spring')
plt.bar(year, summer, bottom=spring, label='summer')
plt.bar(year, autumn, bottom=spring+summer, label='autumn')
plt.bar(year, winter, bottom=spring+summer+autumn, label='winter')
plt.title('precipitation')
plt.xlabel('year')
plt.ylabel('mm')
plt.legend()
plt.show()

# %% [markdown]
# 코드 9-16

# %%
x = np.linspace(-np.pi,np.pi*2,100)

plt.subplot(2,1,1)
plt.plot(x,np.sin(x), label='sin')
plt.legend()
plt.subplot(2,1,2)
plt.plot(x,np.cos(x), label='cos')
plt.legend()
plt.show()

# %% [markdown]
# 코드 9-17

# %%
math = np.array([75, 89, 75, 65, 79])
english = np.array([85, 80, 90, 75, 88])
korean = np.array([72, 90, 70, 88, 93])
x = ['math','english', 'korean']

plt.figure(figsize=(5,3))
plt.bar(x, [np.mean(math), np.mean(english), np.mean(korean)])
plt.ylabel('score')
plt.show()

# %% [markdown]
# 코드 9-18

# %%
x = np.random.randn(1000)

plt.figure(figsize=(5,3))
plt.hist(x, bins=40, alpha=0.5)
plt.ylabel('frequency')
plt.show()

# %% [markdown]
# 코드 9-19

# %%
score = np.array([71, 80, 60, 90, 65])
result = np.where(score>=90, 'A',
                  np.where(score>=80, 'B',
                    np.where(score>=70,'C','D')))

print(result)
# Out:
# ['C' 'B' 'D' 'A' 'D']

# %% [markdown]
# 코드 9-20

# %%
month = np.arange(1,13)
num_cases = [11, 2920, 6636, 750, 615, 1411, 1044, 5473, 3707, 2444, 7324, 26198]
cum_cases = np.cumsum(num_cases)

plt.figure(figsize=(5,3))
plt.plot(month, num_cases, label='number of cases')
plt.plot(month, cum_cases, label='accumulated number of cases')
plt.xlabel('month')
plt.legend()
plt.show()

# %% [markdown]
# 코드 9-21

# %%
plt.figure(figsize=(5,3))
for i in range(3):
  coin = np.random.randint(0,2,5000)
  ind = np.arange(1, len(coin)+1)
  p_c = np.cumsum(coin)/ind*100
  plt.plot(ind, p_c)
plt.ylim(0,100)
plt.ylabel('%')
plt.show()
